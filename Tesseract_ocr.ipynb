# %%
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)

# %%
import cv2

# %%
# Install Tesseract and pytesseract
# !apt-get install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)

# %%
# Import the necessary libraries
import pytesseract
from PIL import Image

# Set the Tesseract executable path
pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'# default path


# Read the image using Pillow (PIL)
image = Image.open("digital_01.jpg")  # Replace with your image file path
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=728x383>

# %%
# Perform OCR on the image
text = pytesseract.image_to_string(image)

# Print the extracted text
print(text)
# Out:
#
#
#
#
# Disabled
#
#
#
#
#
# Submit
#
#
#
#
#
#
#
# HTML
#
# O f
#
# xt v
#
# https://tutorial.codingfactory.net/_lab/form.htm
